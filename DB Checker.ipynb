# %%
import sqlite3
con = sqlite3.connect("german_tips.db")
cur = con.cursor()
# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM transactions;'):
    print(row)
con.close()
# Out:
# ('TXN-01774', '2005-01-01', 'Conroy', 'Vicente', '1993-10-02', 'MegaMall', 'Manicure', '55.23', 53)
# ('TXN-59909', '2005-01-01', 'Rau', 'Justus', '1998-03-18', 'RobinsonsMall', 'HairColor', '88.09', 53)
# ('TXN-24982', '2005-01-01', 'Goldner', 'Arlene', '2003-05-01', 'MallOfAsia', 'NailColor', '30.12', 53)
# ('TXN-08018', '2005-01-02', 'Feeney', 'Corbin', '2004-10-05', 'StarMall', 'Pedicure', '0.0', 53)
# ('TXN-41893', '2005-01-02', 'Beier', 'Rickey', '1997-07-10', 'MegaMall', 'FootSpa', '0.0', 53)
# ('TXN-14571', '2005-01-02', 'Abbott', 'Josue', '2000-10-03', 'RobinsonsMall', 'NailColor', '30.12', 53)
# ('TXN-35560', '2005-01-02', 'Stiedemann', 'Mary', '2001-03-16', 'MallOfAsia', 'Rebond', '400.23', 53)
# ('TXN-27027', '2005-01-03', 'Langosh', 'Cecelia', '1993-09-16', 'RobinsonsMall', 'Pedicure', '0.0', 1)
# ('TXN-57588', '2005-01-03', 'Wisozk', 'Eduardo', '1996-08-14', 'RobinsonsMall', 'HairColor', '0.0', 1)
# ...
