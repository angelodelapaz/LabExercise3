# %%
import sqlite3
con = sqlite3.connect("german_tips.db")
cur = con.cursor()
# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM german_tips;'):
    print(row)
con.close()
# Out:
# ('TXN-60295', '2006-09-25', 'Lesch', 'Fleta', '1993-05-22', 'SmallMall', 'FootSpa', '100.12')
# ('TXN-60295', '2018-12-07', 'Lesch', 'Fleta', '2008-06-15', 'SmallMall', 'FootSpa', '100.12')
# ('TXN-40462', '2021-08-21', 'Kuhn', 'Tod', '2002-11-25', 'StarMall', 'HairColor', '88.09')
# ('TXN-40462', '2014-09-21', 'Kuhn', 'Tod', '1993-07-06', 'StarMall', 'HairColor', '88.09')
# ('TXN-08102', '2010-04-03', 'Johnson', 'Milton', '2003-07-10', 'RobinsonsMall', 'HairColor', '88.09')
# ('TXN-08102', '2012-04-15', 'Johnson', 'Milton', '2004-10-14', 'RobinsonsMall', 'HairColor', '88.09')
# ('TXN-64262', '2018-11-23', 'Hackett', 'Maci', '2005-06-20', 'SmallMall', 'Rebond', '400.23')
# ('TXN-64262', '2019-10-07', 'Hackett', 'Maci', '1996-09-19', 'SmallMall', 'Rebond', '400.23')
# ('TXN-08158', '2023-08-05', 'Batz', 'Timmothy', '2008-10-06', 'MayMall', 'NailColor', '30.12')
# ('TXN-08158', '2015-08-21', 'Batz', 'Timmothy', '1997-12-22', 'MayMall', 'NailColor', '30.12')
# ...
